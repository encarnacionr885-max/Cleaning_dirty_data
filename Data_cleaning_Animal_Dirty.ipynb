# %%
# ===============================
# Full Animal Dataset Cleaning + Outlier Detection
# ===============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# 1️⃣ Load CSV as strings to inspect raw data
df = pd.read_csv("animal_data_dirty1.csv", sep=';', dtype=str)

# Preview first 10 rows
print("First 10 rows of raw data:")
print(df.head(10))

# Show original column names
print("\nOriginal column names:")
print(df.columns.tolist())

# 2️⃣ Standardize column names (fix typos, remove spaces)
df.columns = df.columns.str.strip()  # remove extra spaces
df.rename(columns={
    'Animal type': 'Animal_Type',
    'Weight kg': 'Weight_kg',
    'Body Length cm': 'Body_Length_cm',
    'Animal code': 'Animal_Code',
    'Animal name': 'Animal_name',
    'Observation date': 'Observation_Date',
    'Data compiled by': 'Data_Completed_by'
}, inplace=True)

print("\nRenamed columns:")
print(df.columns.tolist())

# 3️⃣ Replace string 'NaN' and empty strings with actual np.nan
df.replace('NaN', np.nan, inplace=True)
for col in df.select_dtypes(include='string').columns:
    df[col] = df[col].str.strip()
    df[col] = df[col].replace('', np.nan)

# 4️⃣ Check missing values
print("\nMissing values per column:")
print(df.isna().sum())

# 5️⃣ Drop empty columns (e.g., Animal_Code is completely empty)
if df['Animal_Code'].isna().all():
    df.drop(columns=['Animal_Code'], inplace=True)
    print("\nDropped 'Animal_Code' column because it is completely empty.")

# 6️⃣ Fill categorical columns safely
categorical_cols = ['Gender', 'Animal_Type', 'Animal_name', 'Country']
for col in categorical_cols:
    if df[col].mode().empty:
        df[col] = df[col].fillna('Unknown')
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

# 7️⃣ Convert numeric columns to numbers and fill missing values with mean
numeric_cols = ['Weight_kg', 'Body_Length_cm', 'Latitude', 'Longitude']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    df[col] = df[col].fillna(df[col].mean())

# 8️⃣ Convert Observation_Date to datetime and fill missing with fixed date
df['Observation_Date'] = pd.to_datetime(df['Observation_Date'], errors='coerce', dayfirst=True)
df['Observation_Date'] = df['Observation_Date'].fillna(pd.Timestamp('2024-01-01'))

# 9️⃣ Verify no missing values left
print("\nMissing values per column after cleaning:")
print(df.isna().sum())

# 🔟 Preview cleaned data
print("\nPreview of cleaned data:")
print(df.head())

# ===============================
# Outlier Detection
# ===============================

# IQR Method
for col in ['Weight_kg', 'Body_Length_cm']:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    IQR = q3 - q1
    factor = 1.5  # usual IQR factor
    lower = q1 - (IQR * factor)
    upper = q3 + (IQR * factor)
    
    df[col + "_IQR_clean"] = df[col].where((df[col] >= lower) & (df[col] <= upper))

# Z-score Method
for col in ['Weight_kg', 'Body_Length_cm']:
    z_scores = stats.zscore(df[col].fillna(df[col].mean()))
    df[col + "_Z_clean"] = df[col].where(abs(z_scores) < 3)

# ===============================
# Visualization
# ===============================

for col in ['Weight_kg', 'Body_Length_cm']:
    plt.figure(figsize=(12,5))
    
    plt.subplot(1, 2, 1)
    plt.boxplot(df[col].dropna())
    plt.title(f"{col} - Original")
    
    plt.subplot(1, 2, 2)
    plt.boxplot(df[col + "_IQR_clean"].dropna())
    plt.title(f"{col} - IQR Cleaned")
    
    plt.show()

# ===============================
# Finished
# ===============================

print("\nData cleaning and outlier detection completed!")
# Out:
# First 10 rows of raw data:
#        Animal type  Country Weight kg Body Length cm          Gender  \
# 0              NaN      NaN       NaN            NaN             NaN
# 1              NaN      NaN       NaN            NaN             NaN
# 2   European bison   Poland       930            335            male
# 3   European bison   Poland       909            311  not determined
# 4  European bison™   Poland       581            277          female
# 5  European bisson   Poland       900            295            male
# 6  European buster   Poland       620            250          female
# 7             lynx  Hungary        24             76            male
# 8            lynx?  Hungary        23             82          female
# 9      red squirel   Poland     0.308             22          female
#
#   Animal code   Latitude  Longitude Animal name Observation date  \
# 0         NaN        NaN        NaN         NaN       03.01.2024
# 1         NaN        NaN        NaN         NaN       03.02.2024
# 2         NaN  52.828845  23.820144       Szefu       01.03.2024
# 3         NaN  52.830509  23.826849         NaN       01.03.2024
# 4         NaN  52.834109  23.807093         NaN       01.03.2024
# 5         NaN  52.834759  23.817201         NaN       01.03.2024
# 6         NaN  52.834960  23.820750         NaN       01.03.2024
# 7         NaN  48.505494  20.551966         NaN       01.03.2024
# 8         NaN  48.506529  20.554548         NaN       01.03.2024
# 9         NaN  52.241273  21.055745       Basia       01.03.2024
#
#   Data compiled by
# 0    James Johnson
# 1    James Johnson
# 2     Anne Anthony
# 3     Anne Anthony
# 4     Anne Anthony
# 5     Anne Anthony
# 6     Anne Anthony
# 7     Anne Anthony
# 8     Anne Anthony
# 9     Anne Anthony
#
# Original column names:
# ['Animal type', 'Country', 'Weight kg', 'Body Length cm', 'Gender', 'Animal code', 'Latitude', 'Longitude', 'Animal name', 'Observation date', 'Data compiled by']
#
# Renamed columns:
# ['Animal_Type', 'Country', 'Weight_kg', 'Body_Length_cm', 'Gender', 'Animal_Code', 'Latitude', 'Longitude', 'Animal_name', 'Observation_Date', 'Data_Completed_by']
#
# Missing values per column:
# Animal_Type            20
# Country                12
# Weight_kg              27
# Body_Length_cm         27
# Gender                 19
# Animal_Code          1011
# Latitude               98
# Longitude              98
# Animal_name           959
# Observation_Date        0
# Data_Completed_by       0
# dtype: int64
#
# Dropped 'Animal_Code' column because it is completely empty.
#
# Missing values per column after cleaning:
# Animal_Type          0
# Country              0
# Weight_kg            0
# Body_Length_cm       0
# Gender               0
# Latitude             0
# Longitude            0
# Animal_name          0
# Observation_Date     0
# Data_Completed_by    0
# dtype: int64
#
# Preview of cleaned data:
#        Animal_Type Country   Weight_kg  Body_Length_cm          Gender  \
# 0     red squirrel  Poland   39.745503       39.107724            male
# 1     red squirrel  Poland   39.745503       39.107724            male
# 2   European bison  Poland  930.000000      335.000000            male
# 3   European bison  Poland  909.000000      311.000000  not determined
# 4  European bison™  Poland  581.000000      277.000000          female
#
#     Latitude  Longitude Animal_name Observation_Date Data_Completed_by
# 0  49.393369  18.203280  Bob Bobson       2024-01-03     James Johnson
# 1  49.393369  18.203280  Bob Bobson       2024-02-03     James Johnson
# 2  52.828845  23.820144       Szefu       2024-03-01      Anne Anthony
# 3  52.830509  23.826849  Bob Bobson       2024-03-01      Anne Anthony
# 4  52.834109  23.807093  Bob Bobson       2024-03-01      Anne Anthony
# Data cleaning and outlier detection completed!

# %%
df['Gender'].mode()[0]      
df['Weight_kg'].mean()       
df['Body_Length_cm'].median()
# Out:
# np.float64(21.0)
